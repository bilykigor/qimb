# %%
import qimbs 
import numpy as np
import pandas as pd
from ggplot import *

# %%
reload(qimbs)
# Out:
# <module 'qimbs' from 'qimbs.py'>

# %%
#!Importing data
df = qimbs.import_month(7)

# %%
#Adding Timestamp column
df = qimbs.create_timestamp(df)

# %%
#Getting imbalance info
imbalanceMsg = qimbs.get_imbelanceMSG(df,0)

# %%
#Creating features
fdf,Features = qimbs.create_features2(imbalanceMsg)

# %%
fdf=fdf[(abs(fdf.Far)<0.2) & (abs(fdf.Near)<0.2) &
        (abs(fdf.PrevCLC)<0.2) & (abs(fdf.PrevOPC)<0.2) &
        (abs(fdf.Bid)<0.2) & (abs(fdf.Ask)<0.2)]
fdf.index = range(fdf.shape[0])

# %%
X = fdf[['Move','Bid', 'Ask',  'Near', 'Far',  'PrevCLC',  'PrevOPC']]
#X['Bias'] = np.ones((X.shape[0],1))

y = fdf['Move']

dates = sorted(list(set(fdf.Date)))
datesDF = qimbs.dates_tmp_df(fdf)

ERRORS = pd.DataFrame(columns=['Model','TrainError','TestError'])

# %%
ggplot(fdf,aes(x='Move')) + geom_histogram(binwidth = 0.05)
# Out:
# <ggplot: (11505269)>

# %%
X.describe()
# Out:
#               Move          Bid          Ask         Near          Far  \
# count  2538.000000  2538.000000  2538.000000  2538.000000  2538.000000
# mean     -0.000961    -0.019032     0.026467    -0.000821    -0.000766
# std       0.007936     0.036367     0.042443     0.010971     0.014571
# min      -0.085000    -0.198276    -0.108833    -0.125000    -0.134838
# 25%      -0.002717    -0.021090     0.000000    -0.002898    -0.003849
# 50%       0.000000    -0.002454     0.006078     0.000000    -0.000645
# 75%       0.000873     0.000000     0.035542     0.000909     0.001960
# max       0.060714     0.052787     0.200000     0.142857     0.182965
#
#            PrevCLC      PrevOPC
# count  2538.000000  2538.000000
# mean     -0.001697     0.000015
# std       0.027206     0.037783
# min      -0.196352    -0.192597
# 25%      -0.008297    -0.014019
# 50%       0.000000     0.001201
# 75%       0.007481     0.015451
# max       0.197183     0.198312

# %%
axes = pd.tools.plotting.scatter_matrix(X, color="brown")

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
XN=scaler.transform(X)
X_norm = pd.DataFrame(XN,columns=X.columns)
X_norm.describe()
# Out:
#                Move           Bid           Ask          Near           Far  \
# count  2.538000e+03  2.538000e+03  2.538000e+03  2.538000e+03  2.538000e+03
# mean  -3.592258e-16  9.378279e-16 -8.486338e-18 -7.642079e-17  2.563399e-17
# std    1.000197e+00  1.000197e+00  1.000197e+00  1.000197e+00  1.000197e+00
# min   -1.059218e+01 -4.929748e+00 -3.188457e+00 -1.132106e+01 -9.203182e+00
# 25%   -2.213593e-01 -5.658469e-02 -6.237163e-01 -1.893058e-01 -2.116189e-01
# 50%    1.211390e-01  4.559711e-01 -4.804735e-01  7.486566e-02  8.329075e-03
# 75%    2.312248e-01  5.234507e-01  2.138651e-01  1.577038e-01  1.870959e-01
# max    7.773511e+00  1.975266e+00  4.089460e+00  1.309878e+01  1.261197e+01
#
#             PrevCLC       PrevOPC
# count  2.538000e+03  2.538000e+03
# mean  -1.425617e-16 -1.442678e-16
# std    1.000197e+00  1.000197e+00
# min   -7.156180e+00 -5.098867e+00
# 25%   -2.426290e-01 -3.715161e-01
# 50%    6.239406e-02  3.139223e-02
# 75%    3.374121e-01  4.086106e-01
# max    7.311524e+00  5.249367e+00

# %%
ggplot(X_norm,aes(x='PrevCLC')) + geom_histogram(binwidth=0.05)
# Out:
# <ggplot: (36467453)>

# %%
for v in X.columns:
    X_norm[v]=qimbs.sigmoid(X_norm[v]*0.5)
X_norm.describe()
# Out:
#               Move          Bid          Ask         Near          Far  \
# count  2538.000000  2538.000000  2538.000000  2538.000000  2538.000000
# mean      0.500623     0.504755     0.495969     0.499354     0.498852
# std       0.099714     0.107804     0.111936     0.094493     0.091850
# min       0.004986     0.078358     0.168790     0.003469     0.009936
# 25%       0.472358     0.492927     0.422661     0.476354     0.473572
# 50%       0.515138     0.556751     0.440228     0.509357     0.501041
# 75%       0.528871     0.565060     0.526708     0.519703     0.523370
# max       0.979900     0.728620     0.885414     0.998571     0.998178
#
#            PrevCLC      PrevOPC
# count  2538.000000  2538.000000
# mean      0.500787     0.500289
# std       0.103169     0.110970
# min       0.027170     0.072465
# 25%       0.469709     0.453694
# 50%       0.507799     0.503924
# 75%       0.542077     0.550899
# max       0.974809     0.932433

# %%
axes = pd.tools.plotting.scatter_matrix(X_norm, color="brown")

# %%
y = X['Move']
X = X[['Bid', 'Ask',  'Near', 'Far', 'PrevOPC', 'PrevCLC']]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=7)
pca.fit(XN)
plt.plot(pca.explained_variance_ratio_) 
X_pca=pd.DataFrame(pca.transform(XN),columns=['v1','v2','v3','v4','v5','v6','v7'])
X_pca.describe()
# Out:
#                  v1            v2            v3            v4            v5  \
# count  2.538000e+03  2.538000e+03  2.538000e+03  2.538000e+03  2.538000e+03
# mean  -6.064670e-16  1.974523e-16  1.747136e-16  4.049329e-17  1.406482e-15
# std    1.552729e-01  1.392038e-01  1.263862e-01  8.278104e-02  6.526208e-02
# min   -7.924038e-01 -5.457107e-01 -3.625971e-01 -4.592508e-01 -4.622010e-01
# 25%   -4.929696e-02 -7.490524e-02 -8.234220e-02 -2.648729e-02 -2.905823e-02
# 50%   -7.857626e-03  1.082031e-02 -4.228456e-02 -2.000355e-03 -2.915836e-03
# 75%    4.810039e-02  6.525442e-02  6.904170e-02  2.343440e-02  2.694501e-02
# max    8.960716e-01  6.252947e-01  5.806923e-01  3.538456e-01  5.267986e-01
#
#                  v6            v7
# count  2.538000e+03  2.538000e+03
# mean   3.460690e-15 -1.299153e-15
# std    5.746391e-02  2.330561e-02
# min   -4.438929e-01 -2.298400e-01
# 25%   -2.025583e-02 -4.499430e-03
# 50%   -2.332651e-03  1.439457e-05
# 75%    1.760894e-02  5.355062e-03
# max    6.208836e-01  2.916031e-01

# %%
pca.components_
# Out:
# array([[-0.55530124,  0.17011085,  0.11468426, -0.58161466, -0.54857484,
#         -0.08553982, -0.05498477],
#        [ 0.01955522,  0.23788015, -0.39469826,  0.06036264,  0.06494609,
#         -0.58496616, -0.66120864],
#        [-0.01163486, -0.63517638,  0.62724356,  0.00902025,  0.01613831,
#         -0.29041887, -0.34394211],
#        [ 0.25991851,  0.68879875,  0.64057793,  0.09071136,  0.01285628,
#         -0.19124914,  0.0518507 ],
#        [-0.15503715, -0.11283292, -0.09162522,  0.05044735,  0.0950885 ,
#         -0.71564371,  0.65658538],
#        [-0.7634087 ,  0.15301363,  0.13643414,  0.32003357,  0.49763325,
#          0.13202861, -0.08768019],
#        [ 0.12936677,  0.02093176,  0.0166368 , -0.73810866,  0.66162017,
#          0.00084574, -0.0017192 ]])

# %%
ggplot(X[y>=0.5], aes('Near','Far')) + geom_point(size=1, color='green') +\
geom_point(X[y<0.5], aes('Near','Far'),size=1, color='red')
# Out:
# <repr(<ggplot.ggplot.ggplot at 0x59256d0>) failed: KeyError: 0>

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.svm import SVR
#r = SVR().fit(X,y)
r = RF(n_jobs=4).fit(X,y)
pred = r.predict(X)
print 'MAE: %s, MSE: %s, R2: %s' % \
(mean_absolute_error(y,pred),mean_squared_error(y,pred),\
 r2_score(y,pred))
# Out:
# MAE: 0.0137915854175, MSE: 0.000740840158884, R2: 0.925460987832

# %%
plt.scatter(y,r.predict(X)) #+ geom_abline(color='red')
